# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Kidney Tumor segmentation/Results/Dice_soft/eval_score.csv')
df = df[0:44]
TK = df['Tumor_and_Kidney_Dice']
K = df['Kidney Dice']
T = df['Tumor_Dice']
print()

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
fig1, ax1 = plt.subplots()
ax1.set_title('Basic Plot')
ax1.boxplot([TK, K , T])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f3780346a90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f37802d44e0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f37802d4f60>,
# ...
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f37802d4be0>,
# ...
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f3780346da0>,
# ...
#   <matplotlib.lines.Line2D at 0x7f37802f2320>]}

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Kidney Tumor segmentation/Results/Standard_log_cosh_dice_loss/train(160)/eval_score_kits19.csv')
a = df[45:46]
df = df[0:44]
TK = df['Tumor_and_Kidney_Dice']
K = df['Kidney Dice']
T = df['Tumor_Dice']
import numpy as np
import matplotlib.pyplot as plt
import math
fig1, ax1 = plt.subplots()
ax1.set_title('Basic Plot')
ax1.boxplot([TK, K , T])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f3770eb0978>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f3770ebe3c8>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f3770ebee48>,
# ...
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f3770ebeac8>,
# ...
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f3770eb0c88>,
# ...
#   <matplotlib.lines.Line2D at 0x7f3770e55fd0>]}

# %%
import seaborn as sns

sns.boxplot(data=[TK, K , T])

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Kidney Tumor segmentation/Results/Standard_log_cosh_dice_loss/train(160)/eval_score_kits19.csv')


sns.barplot(data=[[0.521045403489034]	, [0.406598944]], 
            capsize=0.1, edgecolor='k')

# %%
import seaborn as sns
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Kidney Tumor segmentation/Results/SIZ_160_299.csv')
a = df['range_start']
c = df['Total_cases']
b = df['range_end']

sns.displot(b, x=c, bins=19)
