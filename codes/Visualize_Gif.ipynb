# %%
import glob
import moviepy.editor as mpy
from pathlib import Path

# %%
y = []
paths = Path('/content/drive/MyDrive/Colab Notebooks/Kidney Tumor segmentation/Results/Pred_Results/dice_loss').glob('**/*.png')
for path in paths:
    y.append(path)

# %%
gif_name = 'case_166'
fps = 12
file_list = glob.glob('/content/drive/MyDrive/Colab Notebooks/Kidney Tumor segmentation/Visualize/**.png') 
list.sort(file_list, key=lambda x: int(x.split('/')[7].split('.png')[0]))
clip = mpy.ImageSequenceClip(file_list, fps=fps)
clip.write_gif(f'/content/drive/MyDrive/Colab Notebooks/Kidney Tumor segmentation/{gif_name}.gif', fps=fps)
